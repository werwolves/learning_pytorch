# %%
from torchtext import data,datasets

# %%
from torchtext.data import  BucketIterator
from torchtext.datasets import TranslationDataset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1532\2697201311.py in <module>
# ----> 1 from torchtext.data import  BucketIterator
#       2 from torchtext.datasets import TranslationDataset
#
# ImportError: cannot import name 'BucketIterator' from 'torchtext.data' (f:\my_softers\project_IDE\Anconda\envs\jp_layout_pytorch\lib\site-packages\torchtext\data\__init__.py)
