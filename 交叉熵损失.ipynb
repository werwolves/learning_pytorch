# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
pred = torch.randn(4, 7, 224, 224)
target = torch.randint(0, 7, (4, 224, 224))
print(pred.shape, target.shape)
# Out:
# torch.Size([4, 7, 224, 224]) torch.Size([4, 224, 224])

# %%
nn.CrossEntropyLoss()(pred, target)
# Out:
# tensor(2.3414)

# %%
nn.CrossEntropyLoss(axis=1)(pred, target)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 nn.CrossEntropyLoss(axis=1)(pred, target)
#
# TypeError: __init__() got an unexpected keyword argument 'axis'
