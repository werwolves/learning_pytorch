# %% [markdown]
# <span style='color:red'>1.感受野的计算</span>
# <span style='font-size:14px'>就是指特征图上的一个点，对应输入特征图的区域大小
# 1> 第一层卷积层， 感受野的大小等于滤波器的大小
# 2> 深层卷积层的感受野大小与它之前所有层的滤波器大小和步长有关</span>
# <span style='color:red'>2.AUC是什么？怎么计算</span>
# <span style='font-size:14px'>
# <img src="1.png" style="width:50%;height:auto;">
# </span>
