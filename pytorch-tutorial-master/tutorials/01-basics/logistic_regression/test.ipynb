# %%
import torch
import torch.nn as nn

# %%
model = nn.Linear(10,1)
optimer = torch.optim.Adam(model.parameters(),lr=0.01)

# %%
[ x for x in model.parameters() ]
# Out:
# [Parameter containing:
#  tensor([[ 0.0953,  0.2674,  0.1436,  0.2277, -0.2994,  0.2941, -0.1795, -0.0311,
#           -0.2289,  0.2634]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.1573], requires_grad=True)]

# %%
optimer.param_groups[0]['lr']
# Out:
# 0.01

# %%
optimer._step_count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_116\43251816.py in <module>
# ----> 1 optimer._step_count
#
# AttributeError: 'Adam' object has no attribute '_step_count'

# %%
dir(optimer)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_hook_for_profile',
#  '_zero_grad_profile_name',
#  'add_param_group',
#  'defaults',
#  'load_state_dict',
#  'param_groups',
#  'state',
#  'state_dict',
#  'step',
#  'zero_grad']

# %%
optimer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.01
#     weight_decay: 0
# )
