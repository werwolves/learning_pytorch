# %%
import torch
import torch.nn as nn
# ------------------- MSE Loss
output = torch.tensor((1.,1.),requires_grad=True)
target = torch.tensor((2.,2.))
print(output,output.requires_grad)
print(target,target.requires_grad)
# Out:
# tensor([1., 1.], requires_grad=True) True
# tensor([2., 2.]) False

# %%
loss = nn.MSELoss()

# %%
# help(nn.MSELoss)

# %%
loss(output, target)
# Out:
# tensor(1., grad_fn=<MseLossBackward>)
