# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
model = nn.Linear(4,2)
# print([ x for x in model.parameters() ])
optimizer = optim.SGD(model.parameters(),lr=0.001)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.1,patience=5)
for epoch in range(100):
    val_acc = compute_validation_performance() # 假设该函数可以计算验证机准确率
    # 调用 学习率 调整函数
    scheduler.step(val_acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15856\3974332076.py in <module>
#       4 scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.1,patience=5)
#       5 for epoch in range(100):
# ----> 6     val_acc = compute_validation_performance() # 假设该函数可以计算验证机准确率
#       7     # 调用 学习率 调整函数
#       8     scheduler.step(val_acc)
#
# NameError: name 'compute_validation_performance' is not defined
