# %%
import numpy as np
import cv2
im1 = cv2.imread('./imgs/0.jpg')
"""
sift 最大的问题就是速度慢，因此才有 SURF

"""
cv2.__version__
# Out:
# '4.10.0'

# %%
# pip install opencv-contrib-python

# %%
suft = cv2.xfeatures2d.SURF_create()  # 暂时该版本的opencv还不能用法
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 suft = cv2.xfeatures2d.SURF_create()
#
# AttributeError: module 'cv2' has no attribute 'xfeatures2d'
