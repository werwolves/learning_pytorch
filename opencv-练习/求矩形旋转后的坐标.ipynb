# %%
import cv2  
import numpy as np  
  
# 旋转矩形的角度、中心点和大小  
angle = 45.0  # 旋转角度（度）  
width, height = 100, 50  # 矩形大小（宽，高）  
x, y = 50, 50  # 矩形中心点坐标（x，y）  
  
# 计算旋转矩形的四个角点坐标  
# points = cv2.boxPoints(angle, (width, height), (x, y))  
points = cv2.boxPoints(((x, y),(width, height), angle))   # # (中心点坐标, (宽度, 高度), 旋转角度)  


# 打印角点坐标  
for point in points:  
    print(point)
# Out:
# [-3.0330086 32.322334 ]
# [32.322334  -3.0330086]
# [103.033005  67.677666]
# [ 67.677666 103.033005]

# %%
import cv2  
import numpy as np  
  
# 创建一个旋转矩形对象  
rect = ((100, 50), (100, 50), 45)  # (x, y, width, height, angle)  
  
# 获取旋转矩形的四个角点坐标  
points = cv2.boxPoints(rect)  
  
# 打印角点坐标  
for point in points:  
    print(point)
# Out:
# [46.966988 32.322334]
# [82.322334  -3.0330086]
# [153.03302   67.677666]
# [117.677666 103.033005]

# %%
from PIL import Image

# %%
img_path = './res_tps_img.jpeg'
pil_img = Image.open(img_path)
print(pil_img.size)
pil_img
# Out:
# (640, 272)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x272>

# %%
rotated_img = pil_img.rotate(45)
print(rotated_img.size)
rotated_img
# Out:
# (640, 272)
# <PIL.Image.Image image mode=RGB size=640x272>

# %%
rotated_img = pil_img.rotate(45,expand=1)
print(rotated_img.size)
rotated_img
# Out:
# (646, 646)
# <PIL.Image.Image image mode=RGB size=646x646>
