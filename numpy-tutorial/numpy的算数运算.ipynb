# %%
import numpy as np

# %%
a = np.array([[1,2],[3,4]])
b = np.array([[10,20],[30,40]])

# %%
a+b
# Out:
# array([[11, 22],
#        [33, 44]])

# %%
a + 5
# Out:
# array([[6, 7],
#        [8, 9]])

# %% [markdown]
# <span style='color:red;'>2. 看看numpy的广播机制</span>

# %%
a = np.array([[1,2]])
b = np.array([[1,2],[3,4]])
a+b
# Out:
# array([[2, 4],
#        [4, 6]])

# %%
a = np.array([1,2])
b = np.array([[1,2],[3,4]])
a+b
# Out:
# array([[2, 4],
#        [4, 6]])
