# %%
import numpy as np

# %%
points = [1.2323456, 2.35545678, 1.44456789]
np.round(points, decimals=5) # decimals 表示保留小数点后几位，做四舍五入!!!!
# Out:
# array([1.23235, 2.35546, 1.44457])

# %%
np.array(points).astype(np.int32)
# Out:
# array([1, 2, 1])
