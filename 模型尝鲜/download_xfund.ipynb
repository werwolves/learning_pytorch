# %%
# 修复导入顺序和错误处理
from datasets import load_dataset
import warnings

# 忽略 tqdm 警告（可选）
warnings.filterwarnings("ignore", message="IProgress not found")

try:
    # 尝试加载 XFund 数据集
    dataset = load_dataset("xfund", "zh")  # 中文版
    print("数据集加载成功")
    print(dataset)
except Exception as e:
    print(f"数据集加载失败: {e}")
    print("XFund 数据集可能需要特殊访问权限或不存在于 Hugging Face Hub")
# Out:
# 数据集加载失败: Dataset 'xfund' doesn't exist on the Hub or cannot be accessed.
# XFund 数据集可能需要特殊访问权限或不存在于 Hugging Face Hub
