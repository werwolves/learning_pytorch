# %%
# 字符串练习
sentences = ["apple banana fruit", "banana orange fruit", "orange banana fruit",
                "dog cat animal", "cat monkey an"]
# " ".join() 将可迭代对象中间插上元素" "
" ".join(sentences)
# Out:
# 'apple banana fruit banana orange fruit orange banana fruit dog cat animal cat monkey an'

# %%
" ".join("abcd")
# Out:
# 'a b c d'

# %%
list(set('abbc'))
# Out:
# ['c', 'a', 'b']
